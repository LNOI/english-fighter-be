# %%
# Config

import os
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-3.5-turbo")

os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = ""

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from English into Italian"),
    HumanMessage(content="hi!"),
]
model.invoke(messages)
# Out:
# AIMessage(content='Ciao!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 20, 'total_tokens': 23}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-64ec216f-1b2d-4f53-ba5d-af84b382c2f5-0', usage_metadata={'input_tokens': 20, 'output_tokens': 3, 'total_tokens': 23})

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()
result = model.invoke(messages)
parser.invoke(result)

# %%
import random


questions = {
    '1' : {
        'question' : 'This is a question 1',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'A',

    },
    '2' : {
        'question' : 'This is a question 2',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'B',
    },
    '3' : {
        'question' : 'This is a question 3',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'C',
    },
    '4' : {
        'question' : 'This is a question 4',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'D',
    },
    '5' : {
        'question' : 'This is a question 5',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'A',
    },
    '6' : {
        'question' : 'This is a question 6',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'B',
    },
    '7' : {
        'question' : 'This is a question 7',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'C',
    },
    '8' : {
        'question' : 'This is a question 8',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'D',
    },
    '9' : {
        'question' : 'This is a question 9',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'A',
    },
    '10' : {
        'question' : 'This is a question 10',
        'answer' : {
            'A': 'This is answer A',
            'B': 'This is answer B',
            'C': 'This is answer C',
            'D': 'This is answer D',
        },
        'correct' : 'B',
    },
}

groups = {
    '1' : {
        "question" : "This is a group 1",
        "number_of_questions" : 2,
        "questions" : ['1','2']
    },
    '2' : {
        "question" : "This is a group 2",
        "number_of_questions" : 2,
        "questions" : ['3','4']
    },
    '3' : {
        "question" : "This is a group 3",
        "number_of_questions" : 1,
        "questions" : ['5']
    },
    '4' : {
        "question" : "This is a group 4",
        "number_of_questions" : 1,
        "questions" : ['6']
    },
    '5' : {
        "question" : "This is a group 5",
        "number_of_questions" : 1,
        "questions" : ['7']
    },
    '6' : {
        "question" : "This is a group 6",
        "number_of_questions" : 3,
        "questions" : ['8',
                       '9',
                       '10']
    },
}

parts = {
    '1' : ['1','2','3','4','5','6'],
}

score = 0
for k,v in parts.items():
    print(f"Part {k}")
    for j in v:
        # j is the grup number
        if groups[j]['number_of_questions'] == 1:
            print("Main question: "+ questions[groups[j]['questions'][0]]['question'])
            for k,v in questions[groups[j]['questions'][0]]['answer'].items():
                print(f"{k}: {v}")
            user_choice = random.choice(['A','B','C','D'])
            if user_choice == questions[groups[j]['questions'][0]]['correct']:
                print("Correct")
                score += 1
        else:
            print("Main question: "+ groups[j]['question'])
            for i in groups[j]['questions']:
                print(questions[i]['question'])
                for k,v in questions[i]['answer'].items():
                    print(f"{k}: {v}")
                
                # print(f"Correct answer: {questions[i]['correct']}")
                if questions[i]['correct'] == random.choice(['A','B','C','D']):
                    print("Correct")
                    score += 1
                print("\n")

print(f"Your score is {score}")
# Out:
# Part 1
# Main question: This is a group 1
# This is a question 1
# A: This is answer A
# B: This is answer B
# C: This is answer C
# D: This is answer D
# Correct
#
#
# This is a question 2
# A: This is answer A
# B: This is answer B
# C: This is answer C
# D: This is answer D
#
#
# Main question: This is a group 2
# This is a question 3
# A: This is answer A
# B: This is answer B
# C: This is answer C
# D: This is answer D
#
#
# This is a question 4
# A: This is answer A
# B: This is answer B
# C: This is answer C
# D: This is answer D
#
#
# Main question: This is a question 5
# A: This is answer A
# B: This is answer B
# C: This is answer C
# D: This is answer D
# Correct
# Main question: This is a question 6
# A: This is answer A
# B: This is answer B
# C: This is answer C
# D: This is answer D
# Main question: This is a question 7
# A: This is answer A
# B: This is answer B
# C: This is answer C
# D: This is answer D
# Main question: This is a group 6
# This is a question 8
# ...

# %%
orginal_text = "This is a test for student writing again"
user_speech_text = "This is a student for student speeching test writing again"
## Check the similarity between the orginal text and the user speech text
